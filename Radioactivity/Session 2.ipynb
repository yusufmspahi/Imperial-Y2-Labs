# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = r'/Users/yusufmspahi/PycharmProjects/Imperial-Y2-Labs/Radioactivity/Data/11 - real - 1'
task_11 = pd.read_csv(filepath)

# %%
task_11.head()
# Out:
#    Counts
# 0     8.0
# 1    11.0
# 2    10.0
# 3    12.0
# 4     2.0

# %%
task_11.head()
# Out:
#    Counts
# 0     8.0
# 1    11.0
# 2    10.0
# 3    12.0
# 4     2.0
